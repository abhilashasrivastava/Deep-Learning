# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4", input_shape=IMAGE_SHAPE+(3,))
])

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %%
gold_fish = Image.open("/kaggle/input/gold-fish/goldfish.jpg").resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
gold_fish = np.array(gold_fish)/255
gold_fish.shape
# Out:
# (224, 224, 3)

# %%
gold_fish
# Out:
# array([[[0.28235294, 0.33333333, 0.07058824],
#         [0.31372549, 0.37254902, 0.09019608],
#         [0.34901961, 0.41960784, 0.11764706],
#         ...,
#         [0.32941176, 0.39215686, 0.00392157],
#         [0.32156863, 0.38431373, 0.00392157],
#         [0.30980392, 0.36862745, 0.        ]],
#
#        [[0.28627451, 0.33333333, 0.08235294],
#         [0.3254902 , 0.38039216, 0.10980392],
#         [0.35294118, 0.42352941, 0.12941176],
#         ...,
#         [0.32156863, 0.38039216, 0.00392157],
#         [0.31372549, 0.37254902, 0.00392157],
#         [0.30196078, 0.36078431, 0.        ]],
#
#        [[0.28627451, 0.33333333, 0.08627451],
#         [0.31372549, 0.36862745, 0.10196078],
#         [0.34509804, 0.41568627, 0.12941176],
#         ...,
#         [0.31764706, 0.37647059, 0.00392157],
#         [0.30980392, 0.36862745, 0.00784314],
#         [0.29803922, 0.35686275, 0.00392157]],
#
#        ...,
#
#        [[0.05490196, 0.10980392, 0.01568627],
# ...

# %%
#new axis
gold_fish[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
result=classifier.predict(gold_fish[np.newaxis, ...])
# Out:
# 1/1 [==============================] - 6s 6s/step

# %%
result
# Out:
# array([[ 0.22101471,  2.0474923 ,  9.622566  , ..., -1.4621562 ,
#         -0.281467  , -0.25984913]], dtype=float32)

# %%
result.shape
# Out:
# (1, 1001)

# %%
predict_label_index=np.argmax(result)
predict_label_index
# Out:
# 2

# %%
image_labels = []
with open("/kaggle/input/gold-fish/ImageNetLabels.txt", "r") as f:
    image_labels = f.read().splitlines()
image_labels[:5]
# Out:
# ['background', 'tench', 'goldfish', 'great white shark', 'tiger shark']

# %%
image_labels[predict_label_index]
# Out:
# 'goldfish'

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# Out:
# ...
# 228813984/228813984 [==============================] - 6s 0us/step

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir=pathlib.Path(data_dir)

# %%
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/2756028421_b3d5eea526_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5086249859_d066b37b8a_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/756943228_e15a7b2318.jpg'),
#  PosixPath('datasets/flower_photos/roses/5578760521_e54aca6bed_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/410425647_4586667858.jpg')]

# %%
image_count=len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
roses=list(data_dir.glob('roses/*'))
roses
# Out:
# [PosixPath('datasets/flower_photos/roses/2756028421_b3d5eea526_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5086249859_d066b37b8a_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/756943228_e15a7b2318.jpg'),
#  PosixPath('datasets/flower_photos/roses/5578760521_e54aca6bed_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/410425647_4586667858.jpg'),
#  PosixPath('datasets/flower_photos/roses/1485142251_ca89254442.jpg'),
#  PosixPath('datasets/flower_photos/roses/15859434664_67bf3ef29f.jpg'),
#  PosixPath('datasets/flower_photos/roses/6363951285_a802238d4e.jpg'),
#  PosixPath('datasets/flower_photos/roses/14510185271_b5d75dd98e_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/8747396730_966149e6fe_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/14810868100_87eb739f26_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/2535466393_6556afeb2f_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/505517255_cfbb6f6394.jpg'),
# ...

# %%
roses[0:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/2756028421_b3d5eea526_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/5086249859_d066b37b8a_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/756943228_e15a7b2318.jpg'),
#  PosixPath('datasets/flower_photos/roses/5578760521_e54aca6bed_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/410425647_4586667858.jpg')]

# %%
Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240>

# %%
tulips=list(data_dir.glob('tulips/*'))
tulips
# Out:
# [PosixPath('datasets/flower_photos/tulips/15756524087_823cf86bd8_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/7481217920_6f65766a1c_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/8484905084_6a18c62b13_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/8554190977_37ac747799_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/4442928974_9672d630b2_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/5674695558_61397a1584.jpg'),
#  PosixPath('datasets/flower_photos/tulips/5674132053_b40a7d32ca.jpg'),
#  PosixPath('datasets/flower_photos/tulips/3558517884_0c7ca8b862_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/13976522214_ccec508fe7.jpg'),
#  PosixPath('datasets/flower_photos/tulips/14024864234_713158c27f_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/4522764992_e9d70b82c1_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/7166644048_b00a14f01b.jpg'),
#  PosixPath('datasets/flower_photos/tulips/14057246122_8598b665bd.jpg'),
# ...

# %%
tulips[0:4]
# Out:
# [PosixPath('datasets/flower_photos/tulips/15756524087_823cf86bd8_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/7481217920_6f65766a1c_n.jpg'),
#  PosixPath('datasets/flower_photos/tulips/8484905084_6a18c62b13_m.jpg'),
#  PosixPath('datasets/flower_photos/tulips/8554190977_37ac747799_m.jpg')]

# %%
Image.open(str(tulips[4]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x261>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_images_dict['sunflowers']
# Out:
# [PosixPath('datasets/flower_photos/sunflowers/9381481549_5a5d503e42_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/678714585_addc9aaaef.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4872892690_52dc25b0b4.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/7586498522_4dcab1c8d2_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4191299785_a4faca9b74_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/23204123212_ef32fbafbe.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/3311874685_7b9ef10f7e_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/244074259_47ce6d3ef9.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/2950505226_529e013bf7_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/7820523050_76c8caa025.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/4980406384_791774d953.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/15054750690_198b6ab0f2_n.jpg'),
# ...

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets/flower_photos/roses/2756028421_b3d5eea526_n.jpg'

# %%
img=cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (279, 320, 3)

# %%
cv2.resize(img,(224,224)).shape
# Out:
# (224, 224, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(224,224))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
X[0].shape
# Out:
# (224, 224, 3)

# %%
IMAGE_SHAPE+(3,)
# Out:
# (224, 224, 3)

# %%
plt.axis('off')
plt.imshow(X[1])

# %%
plt.axis('off')
plt.imshow(X[5])

# %%
predicted=classifier.predict(np.array([X[0],X[1],X[2]]))
predicted
# Out:
# 1/1 [==============================] - 1s 748ms/step
# array([[ 0.2066606 ,  0.67725194,  2.3488467 , ..., -0.23781955,
#          0.15013978,  2.869306  ],
#        [ 0.20497248,  0.7111871 ,  0.59596896, ..., -1.0753497 ,
#         -1.0085063 ,  2.183338  ],
#        [ 0.2754934 , -0.46444774, -0.03489508, ..., -0.5004663 ,
#         -1.7997187 ,  2.4865088 ]], dtype=float32)

# %%
predicted=np.argmax(predicted,axis=1)
predicted
# Out:
# array([795, 795, 722])

# %%
image_labels[795]
# Out:
# 'shower curtain'

# %%
image_labels[880]
# Out:
# 'umbrella'

# %%
#freezed layer excluding last layer trainable=false means freeze
feature_extractor_model="https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
pretrained_model_without_top_layer=hub.KerasLayer(
    feature_extractor_model,input_shape=(224,224,3),trainable=False)

# %%
num_of_flowers = 5

model = tf.keras.Sequential([
  pretrained_model_without_top_layer,
  tf.keras.layers.Dense(num_of_flowers) #last layer
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_1 (KerasLayer)  (None, 1280)              2257984
#
#  dense (Dense)               (None, 5)                 6405
#
# ...
# Total params: 2264389 (8.64 MB)
# Trainable params: 6405 (25.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
  optimizer="adam",
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

model.fit(X_train_scaled, y_train, epochs=5)
# Out:
# Epoch 1/5
# 86/86 [==============================] - 7s 27ms/step - loss: 0.8004 - acc: 0.6962
# Epoch 2/5
# 86/86 [==============================] - 2s 27ms/step - loss: 0.4038 - acc: 0.8608
# Epoch 3/5
# 86/86 [==============================] - 2s 27ms/step - loss: 0.3152 - acc: 0.8946
# Epoch 4/5
# 86/86 [==============================] - 2s 27ms/step - loss: 0.2647 - acc: 0.9157
# Epoch 5/5
# 86/86 [==============================] - 2s 27ms/step - loss: 0.2283 - acc: 0.9310
